# %%
import numpy as np 
import pandas as pd
from keras.preprocessing import text, sequence
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Bidirectional, Conv1D, GRU
from sklearn.model_selection import train_test_split, StratifiedKFold
from keras.metrics import categorical_accuracy
from keras.regularizers import l1_l2, l2
from keras import backend as K
import tensorflow as tf
import nltk
# Out:
# Using TensorFlow backend.

# %%
train_bs = pd.read_csv('data/2017/2017_tuple_space.csv')
train_art = pd.read_csv('data/2017/2017_article_box.csv')
# test_df = pd.read_csv('test.csv')

maxlen_seq_bs = 333
maxlen_seq_art = 1500

# Loading and converting the inputs to trigrams
train_input_seqs = train_bs['tuples'].values.T
train_target_seqs = train_art['article'].values.T

# # Same for test
# test_input_seqs = test_df['input'].values.T
# test_input_grams = seq2ngrams(test_input_seqs)

# %%
# Initializing and defining the tokenizer encoders and decoders based on the train set
tokenizer_encoder = Tokenizer(char_level=False)
tokenizer_encoder.fit_on_texts(train_input_seqs)
tokenizer_decoder = Tokenizer(char_level = False, num_words=5000)
tokenizer_decoder.fit_on_texts(train_target_seqs)

# Using the tokenizer to encode and decode the sequences for use in training
# Inputs
train_input_data = tokenizer_encoder.texts_to_sequences(train_input_seqs)
train_input_data = sequence.pad_sequences(train_input_data, maxlen = maxlen_seq_bs, padding = 'post')

# Targets
train_target_data = tokenizer_decoder.texts_to_sequences(train_target_seqs)
train_target_data = sequence.pad_sequences(train_target_data, maxlen = maxlen_seq_art, padding = 'post')
train_target_data = to_categorical(train_target_data)

# Use the same tokenizer defined on train for tokenization of test
# test_input_data = tokenizer_encoder.texts_to_sequences(test_input_grams)
# test_input_data = sequence.pad_sequences(test_input_data, maxlen = maxlen_seq, padding = 'post')

# Computing the number of words and number of tags to be passed as parameters to the keras model
n_words = len(tokenizer_encoder.word_index) + 1
n_tags = len(tokenizer_decoder.word_index) + 1

input = Input(shape = (maxlen_seq_bs,))

# %%
tokenizer_decoder.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'and': 3,
#  'to': 4,
#  'in': 5,
#  'of': 6,
#  'on': 7,
#  'with': 8,
#  'points': 9,
#  'for': 10,
#  'said': 11,
#  'was': 12,
#  'game': 13,
#  'his': 14,
#  'had': 15,
#  'he': 16,
#  'it': 17,
#  'we': 18,
#  'that': 19,
#  'at': 20,
#  'i': 21,
#  'first': 22,
#  '3': 23,
#  'but': 24,
#  'from': 25,
#  'quarter': 26,
#  'season': 27,
#  'after': 28,
#  'scored': 29,
#  'up': 30,
#  'just': 31,
#  'night': 32,
#  'as': 33,
#  'games': 34,
#  'by': 35,
#  'out': 36,
#  'have': 37,
#  'they': 38,
#  'second': 39,
#  'left': 40,
#  'their': 41,
#  'is': 42,
#  'rebounds': 43,
#  'who': 44,
#  'this': 45,
#  'two': 46,
#  'back': 47,
#  'lead': 48,
#  '10': 49,
#  'point': 50,
#  'play': 51,
#  'coach': 52,
#  'three': 53,
#  'got': 54,
#  'when': 55,
#  'were': 56,
#  'made': 57,
#  'more': 58,
#  'all': 59,
#  'team': 60,
#  'third': 61,
#  'fourth': 62,
#  'half': 63,
#  'an': 64,
#  'one': 65,
#  'be': 66,
#  'time': 67,
#  'four': 68,
#  'straight': 69,
#  'has': 70,
#  'not': 71,
#  '11': 72,
#  'win': 73,
#  "it's": 74,
#  'nba': 75,
#  'against': 76,
#  'last': 77,
#  'get': 78,
#  'minutes': 79,
#  'five': 80,
#  'going': 81,
#  'you': 82,
#  'next': 83,
#  'him': 84,
#  'over': 85,
#  '12': 86,
#  'shot': 87,
#  'before': 88,
#  'off': 89,
#  '13': 90,
#  '15': 91,
#  'added': 92,
#  'six': 93,
#  'assists': 94,
#  'good': 95,
#  'right': 96,
#  '14': 97,
#  '16': 98,
#  'missed': 99,
#  'led': 100,
#  'played': 101,
#  '2': 102,
#  'are': 103,
#  'shots': 104,
#  'new': 105,
#  'ball': 106,
#  '20': 107,
#  '1': 108,
#  'high': 109,
#  'seven': 110,
#  '17': 111,
#  'tip': 112,
#  'like': 113,
#  'free': 114,
#  'down': 115,
#  "didn't": 116,
#  'eight': 117,
#  'ins': 118,
#  "he's": 119,
#  'been': 120,
#  '18': 121,
#  'about': 122,
#  'since': 123,
#  'did': 124,
#  'us': 125,
#  'our': 126,
#  '19': 127,
#  'so': 128,
#  'playing': 129,
#  'nine': 130,
#  'double': 131,
#  'into': 132,
#  'home': 133,
#  'finished': 134,
#  'run': 135,
#  'career': 136,
#  'what': 137,
#  'seconds': 138,
#  "that's": 139,
#  'pointer': 140,
#  'there': 141,
#  'way': 142,
#  'host': 143,
#  'final': 144,
#  'them': 145,
#  '4': 146,
#  'friday': 147,
#  'pointers': 148,
#  '5': 149,
#  'its': 150,
#  'won': 151,
#  'shooting': 152,
#  '6': 153,
#  'hit': 154,
#  'go': 155,
#  'com': 156,
#  'went': 157,
#  'make': 158,
#  'james': 159,
#  '7': 160,
#  'while': 161,
#  'wednesday': 162,
#  'lakers': 163,
#  'do': 164,
#  'only': 165,
#  'guard': 166,
#  '21': 167,
#  'lost': 168,
#  '22': 169,
#  'percent': 170,
#  'clippers': 171,
#  'then': 172,
#  'start': 173,
#  'road': 174,
#  'guys': 175,
#  'apnews': 176,
#  'nbabasketball': 177,
#  'saturday': 178,
#  "we're": 179,
#  'victory': 180,
#  '8': 181,
#  'no': 182,
#  'lot': 183,
#  'can': 184,
#  'really': 185,
#  'some': 186,
#  'streak': 187,
#  'https': 188,
#  'tag': 189,
#  'also': 190,
#  'put': 191,
#  'bench': 192,
#  'throws': 193,
#  'heat': 194,
#  'knicks': 195,
#  'think': 196,
#  'basketball': 197,
#  'end': 198,
#  'which': 199,
#  'great': 200,
#  'rockets': 201,
#  'big': 202,
#  'than': 203,
#  'warriors': 204,
#  'spurs': 205,
#  'monday': 206,
#  'or': 207,
#  'jazz': 208,
#  '9': 209,
#  'came': 210,
#  'beat': 211,
#  'year': 212,
#  'best': 213,
#  'thunder': 214,
#  'each': 215,
#  'suns': 216,
#  'because': 217,
#  'if': 218,
#  'scoring': 219,
#  'will': 220,
#  'loss': 221,
#  'took': 222,
#  'most': 223,
#  'celtics': 224,
#  '23': 225,
#  'field': 226,
#  '25': 227,
#  '0': 228,
#  "i'm": 229,
#  'los': 230,
#  'miami': 231,
#  'houston': 232,
#  'my': 233,
#  'pacers': 234,
#  'raptors': 235,
#  'bucks': 236,
#  'memphis': 237,
#  'nets': 238,
#  'early': 239,
#  'angeles': 240,
#  'players': 241,
#  'magic': 242,
#  'boston': 243,
#  'without': 244,
#  'portland': 245,
#  'tuesday': 246,
#  'city': 247,
#  'me': 248,
#  'during': 249,
#  'take': 250,
#  'better': 251,
#  'toronto': 252,
#  'blazers': 253,
#  "don't": 254,
#  'bulls': 255,
#  'hornets': 256,
#  'pistons': 257,
#  'san': 258,
#  'kings': 259,
#  'injury': 260,
#  'knee': 261,
#  'sunday': 262,
#  'now': 263,
#  '24': 264,
#  'teams': 265,
#  'pelicans': 266,
#  'nuggets': 267,
#  'including': 268,
#  'cleveland': 269,
#  'golden': 270,
#  'wizards': 271,
#  'hawks': 272,
#  '30': 273,
#  'late': 274,
#  'star': 275,
#  'through': 276,
#  'player': 277,
#  'both': 278,
#  'well': 279,
#  'halftime': 280,
#  'antonio': 281,
#  'still': 282,
#  'mavericks': 283,
#  "we've": 284,
#  'getting': 285,
#  'winning': 286,
#  'dallas': 287,
#  'little': 288,
#  'state': 289,
#  'detroit': 290,
#  'started': 291,
#  'denver': 292,
#  'oklahoma': 293,
#  'phoenix': 294,
#  'ankle': 295,
#  'other': 296,
#  'rookie': 297,
#  'remaining': 298,
#  'center': 299,
#  'defense': 300,
#  'away': 301,
#  'foul': 302,
#  'know': 303,
#  'tonight': 304,
#  'orleans': 305,
#  'g': 306,
#  'utah': 307,
#  'indiana': 308,
#  'grizzlies': 309,
#  'making': 310,
#  'thought': 311,
#  'gave': 312,
#  'sacramento': 313,
#  'much': 314,
#  'minnesota': 315,
#  'atlanta': 316,
#  'how': 317,
#  'milwaukee': 318,
#  'being': 319,
#  'trip': 320,
#  'stretch': 321,
#  '26': 322,
#  'chicago': 323,
#  'washington': 324,
#  'orlando': 325,
#  'could': 326,
#  'day': 327,
#  'layup': 328,
#  'consecutive': 329,
#  'philadelphia': 330,
#  'another': 331,
#  'charlotte': 332,
#  'turnovers': 333,
#  'thursday': 334,
#  'league': 335,
#  'missing': 336,
#  'record': 337,
#  'return': 338,
#  'would': 339,
#  '27': 340,
#  'floor': 341,
#  'timberwolves': 342,
#  'brooklyn': 343,
#  'forward': 344,
#  'long': 345,
#  'paul': 346,
#  'conference': 347,
#  'visit': 348,
#  'tough': 349,
#  'those': 350,
#  '3s': 351,
#  'york': 352,
#  '28': 353,
#  'give': 354,
#  'losing': 355,
#  'f': 356,
#  'where': 357,
#  'coming': 358,
#  'dunk': 359,
#  'j': 360,
#  'starting': 361,
#  'come': 362,
#  'want': 363,
#  'trying': 364,
#  'every': 365,
#  'court': 366,
#  'basket': 367,
#  'held': 368,
#  'many': 369,
#  '76ers': 370,
#  'embiid': 371,
#  'period': 372,
#  'things': 373,
#  'anthony': 374,
#  'hard': 375,
#  'again': 376,
#  'davis': 377,
#  'cavaliers': 378,
#  'westbrook': 379,
#  'never': 380,
#  "wasn't": 381,
#  'able': 382,
#  'break': 383,
#  'least': 384,
#  'help': 385,
#  '29': 386,
#  'even': 387,
#  'lillard': 388,
#  'harden': 389,
#  'see': 390,
#  'range': 391,
#  'open': 392,
#  'keep': 393,
#  'times': 394,
#  'close': 395,
#  'previous': 396,
#  'job': 397,
#  'line': 398,
#  'any': 399,
#  'plays': 400,
#  'throw': 401,
#  'too': 402,
#  'tied': 403,
#  'green': 404,
#  'leading': 405,
#  'kind': 406,
#  'place': 407,
#  'curry': 408,
#  'score': 409,
#  'harris': 410,
#  'returned': 411,
#  'cut': 412,
#  'rest': 413,
#  'behind': 414,
#  'jumper': 415,
#  'playoff': 416,
#  'part': 417,
#  'outscored': 418,
#  '31': 419,
#  'franchise': 420,
#  'ap': 421,
#  'george': 422,
#  '100': 423,
#  'foot': 424,
#  'brown': 425,
#  'simmons': 426,
#  'durant': 427,
#  'very': 428,
#  'history': 429,
#  '40': 430,
#  'chance': 431,
#  'ahead': 432,
#  'within': 433,
#  'trail': 434,
#  'c': 435,
#  "i've": 436,
#  'derozan': 437,
#  'former': 438,
#  'williams': 439,
#  '33': 440,
#  'felt': 441,
#  'advantage': 442,
#  'rivers': 443,
#  "they're": 444,
#  'sprained': 445,
#  'set': 446,
#  'johnson': 447,
#  'here': 448,
#  'irving': 449,
#  "couldn't": 450,
#  'pretty': 451,
#  'around': 452,
#  '32': 453,
#  'defensive': 454,
#  'fifth': 455,
#  '50': 456,
#  'gordon': 457,
#  'lineup': 458,
#  'antetokounmpo': 459,
#  'past': 460,
#  'doing': 461,
#  'needed': 462,
#  "can't": 463,
#  'booker': 464,
#  'until': 465,
#  'towns': 466,
#  'look': 467,
#  'bit': 468,
#  'beal': 469,
#  'years': 470,
#  'called': 471,
#  'need': 472,
#  'sat': 473,
#  'row': 474,
#  'howard': 475,
#  'overtime': 476,
#  'try': 477,
#  '34': 478,
#  'young': 479,
#  'trailed': 480,
#  'sore': 481,
#  'smith': 482,
#  'technical': 483,
#  'wall': 484,
#  'sixers': 485,
#  'jr': 486,
#  'offensive': 487,
#  'thing': 488,
#  'butler': 489,
#  'offense': 490,
#  'gasol': 491,
#  'minute': 492,
#  'kerr': 493,
#  'energy': 494,
#  'crowd': 495,
#  'deficit': 496,
#  '35': 497,
#  'enough': 498,
#  'cousins': 499,
#  'cavs': 500,
#  'teammates': 501,
#  'attempts': 502,
#  'overall': 503,
#  'top': 504,
#  'oladipo': 505,
#  'same': 506,
#  'feel': 507,
#  'couple': 508,
#  'pass': 509,
#  'short': 510,
#  'griffin': 511,
#  'mike': 512,
#  "you're": 513,
#  '37': 514,
#  'sixth': 515,
#  'series': 516,
#  'love': 517,
#  'wanted': 518,
#  'week': 519,
#  'brooks': 520,
#  'eastern': 521,
#  'room': 522,
#  'following': 523,
#  'obviously': 524,
#  'kyle': 525,
#  'fans': 526,
#  'opening': 527,
#  'under': 528,
#  'arc': 529,
#  'playoffs': 530,
#  'jordan': 531,
#  'everybody': 532,
#  'pick': 533,
#  'fouled': 534,
#  'aldridge': 535,
#  'used': 536,
#  'old': 537,
#  'holiday': 538,
#  'mitchell': 539,
#  'pulled': 540,
#  'figures': 541,
#  'despite': 542,
#  'something': 543,
#  'effort': 544,
#  'days': 545,
#  '36': 546,
#  'kept': 547,
#  'jokic': 548,
#  'walker': 549,
#  "team's": 550,
#  'different': 551,
#  'averaging': 552,
#  'triple': 553,
#  'injured': 554,
#  'jackson': 555,
#  'always': 556,
#  'coverage': 557,
#  'drummond': 558,
#  '38': 559,
#  'taking': 560,
#  'helped': 561,
#  'quarters': 562,
#  'ended': 563,
#  'sure': 564,
#  'miss': 565,
#  'together': 566,
#  'seasons': 567,
#  'later': 568,
#  'your': 569,
#  "there's": 570,
#  'few': 571,
#  'guy': 572,
#  'pair': 573,
#  'easy': 574,
#  'ready': 575,
#  'locker': 576,
#  'having': 577,
#  'bad': 578,
#  'work': 579,
#  'man': 580,
#  'let': 581,
#  'everything': 582,
#  'wins': 583,
#  'defensively': 584,
#  'fell': 585,
#  'nov': 586,
#  'tie': 587,
#  'injuries': 588,
#  'rebound': 589,
#  'van': 590,
#  'hand': 591,
#  '39': 592,
#  'earlier': 593,
#  '48': 594,
#  'turned': 595,
#  'starters': 596,
#  'surgery': 597,
#  'thompson': 598,
#  'dec': 599,
#  'finish': 600,
#  'western': 601,
#  'lowry': 602,
#  '99': 603,
#  'russell': 604,
#  'popovich': 605,
#  'gundy': 606,
#  'head': 607,
#  '104': 608,
#  'paint': 609,
#  'aggressive': 610,
#  'shoot': 611,
#  '41': 612,
#  'john': 613,
#  'morris': 614,
#  'knew': 615,
#  'nikola': 616,
#  'seventh': 617,
#  'murray': 618,
#  'done': 619,
#  'these': 620,
#  'midway': 621,
#  'longest': 622,
#  'porzingis': 623,
#  'pull': 624,
#  'especially': 625,
#  'worst': 626,
#  '98': 627,
#  'thomas': 628,
#  'face': 629,
#  'wade': 630,
#  'buzzer': 631,
#  'combined': 632,
#  'looked': 633,
#  'michael': 634,
#  'handed': 635,
#  'kevin': 636,
#  'though': 637,
#  'tried': 638,
#  '97': 639,
#  '94': 640,
#  'malone': 641,
#  'walton': 642,
#  'dropped': 643,
#  '000': 644,
#  'performance': 645,
#  '44': 646,
#  'key': 647,
#  'steals': 648,
#  '105': 649,
#  '103': 650,
#  'wolves': 651,
#  'once': 652,
#  'rim': 653,
#  '95': 654,
#  'snapped': 655,
#  'mccollum': 656,
#  'per': 657,
#  'jan': 658,
#  'found': 659,
#  '101': 660,
#  '102': 661,
#  'grabbed': 662,
#  '43': 663,
#  'giving': 664,
#  '42': 665,
#  'spot': 666,
#  'regular': 667,
#  '107': 668,
#  'stevens': 669,
#  'beyond': 670,
#  'find': 671,
#  'move': 672,
#  'eighth': 673,
#  'feb': 674,
#  'continue': 675,
#  'improved': 676,
#  'trade': 677,
#  "doesn't": 678,
#  'bradley': 679,
#  'lopez': 680,
#  'possession': 681,
#  'practice': 682,
#  'shoulder': 683,
#  'kidd': 684,
#  'weeks': 685,
#  'fouls': 686,
#  '46': 687,
#  'fast': 688,
#  'blocked': 689,
#  'reserve': 690,
#  '96': 691,
#  'spoelstra': 692,
#  'front': 693,
#  'hoiberg': 694,
#  'nowitzki': 695,
#  '106': 696,
#  '52': 697,
#  '108': 698,
#  'donovan': 699,
#  'leonard': 700,
#  'goal': 701,
#  'step': 702,
#  'lue': 703,
#  'opened': 704,
#  'control': 705,
#  'told': 706,
#  'joe': 707,
#  'arena': 708,
#  'level': 709,
#  'struggled': 710,
#  '110': 711,
#  'stop': 712,
#  'blocks': 713,
#  'entered': 714,
#  'lebron': 715,
#  '91': 716,
#  'schroder': 717,
#  'nights': 718,
#  'people': 719,
#  'hitting': 720,
#  'due': 721,
#  'should': 722,
#  'hip': 723,
#  '45': 724,
#  'josh': 725,
#  'mark': 726,
#  'asked': 727,
#  'anything': 728,
#  'happy': 729,
#  'showed': 730,
#  'parker': 731,
#  'andre': 732,
#  'frank': 733,
#  '92': 734,
#  'eric': 735,
#  '109': 736,
#  'low': 737,
#  'driving': 738,
#  'rallied': 739,
#  'timeout': 740,
#  '47': 741,
#  'closed': 742,
#  'draft': 743,
#  '56': 744,
#  'between': 745,
#  'rhythm': 746,
#  'whole': 747,
#  'apiece': 748,
#  'nearly': 749,
#  '93': 750,
#  'probably': 751,
#  'month': 752,
#  'terry': 753,
#  '53': 754,
#  '51': 755,
#  'moving': 756,
#  'scorer': 757,
#  "you've": 758,
#  'chandler': 759,
#  'twitter': 760,
#  'jeff': 761,
#  'vogel': 762,
#  'dragic': 763,
#  'biggest': 764,
#  '54': 765,
#  '60': 766,
#  '90': 767,
#  'strain': 768,
#  "weren't": 769,
#  'markkanen': 770,
#  'mirotic': 771,
#  'looking': 772,
#  '58': 773,
#  'own': 774,
#  'steve': 775,
#  'position': 776,
#  'turner': 777,
#  '111': 778,
#  'veteran': 779,
#  'kuzma': 780,
#  'matter': 781,
#  'middleton': 782,
#  '49': 783,
#  'call': 784,
#  'casey': 785,
#  'allowed': 786,
#  "d'antoni": 787,
#  'offensively': 788,
#  'dennis': 789,
#  'gobert': 790,
#  'stops': 791,
#  'less': 792,
#  'march': 793,
#  'already': 794,
#  'nothing': 795,
#  "they've": 796,
#  'received': 797,
#  'barnes': 798,
#  'thibodeau': 799,
#  'bledsoe': 800,
#  'baskets': 801,
#  'definitely': 802,
#  'expected': 803,
#  'moved': 804,
#  'group': 805,
#  'wiggins': 806,
#  '89': 807,
#  'stay': 808,
#  'reserves': 809,
#  "we'll": 810,
#  'why': 811,
#  'hardaway': 812,
#  'sidelined': 813,
#  'hurt': 814,
#  'dwight': 815,
#  'bogdanovic': 816,
#  'snyder': 817,
#  'strong': 818,
#  "haven't": 819,
#  'attempt': 820,
#  'carlisle': 821,
#  'saw': 822,
#  'beating': 823,
#  'yet': 824,
#  'gets': 825,
#  '86': 826,
#  't': 827,
#  'finally': 828,
#  'dunn': 829,
#  'horford': 830,
#  'push': 831,
#  'evans': 832,
#  'say': 833,
#  'might': 834,
#  'fun': 835,
#  'rubio': 836,
#  'ginobili': 837,
#  "nba's": 838,
#  'traded': 839,
#  'soreness': 840,
#  'gentry': 841,
#  'homestand': 842,
#  'triano': 843,
#  'began': 844,
#  'extended': 845,
#  'reach': 846,
#  'matched': 847,
#  'ingram': 848,
#  'tyler': 849,
#  'mvp': 850,
#  'ourselves': 851,
#  '88': 852,
#  'debut': 853,
#  '57': 854,
#  'allen': 855,
#  '113': 856,
#  'almost': 857,
#  'bruised': 858,
#  '87': 859,
#  'does': 860,
#  'absence': 861,
#  'digits': 862,
#  'devin': 863,
#  'moment': 864,
#  'west': 865,
#  '55': 866,
#  'confidence': 867,
#  'whiteside': 868,
#  'important': 869,
#  'luke': 870,
#  'answered': 871,
#  'feeling': 872,
#  '115': 873,
#  'rally': 874,
#  'makes': 875,
#  'budenholzer': 876,
#  'randolph': 877,
#  'became': 878,
#  'nurkic': 879,
#  'closing': 880,
#  'single': 881,
#  'defending': 882,
#  'lane': 883,
#  'www': 884,
#  'atkinson': 885,
#  'near': 886,
#  'hood': 887,
#  'responded': 888,
#  '114': 889,
#  '82': 890,
#  'harrison': 891,
#  'stotts': 892,
#  'al': 893,
#  '112': 894,
#  'randle': 895,
#  'huge': 896,
#  'sprain': 897,
#  'show': 898,
#  '85': 899,
#  'fred': 900,
#  '84': 901,
#  'capped': 902,
#  'slow': 903,
#  'followed': 904,
#  'along': 905,
#  'teammate': 906,
#  'scott': 907,
#  '116': 908,
#  'prince': 909,
#  'chris': 910,
#  'total': 911,
#  'ends': 912,
#  'concussion': 913,
#  'looks': 914,
#  'digit': 915,
#  'meetings': 916,
#  'losses': 917,
#  'signed': 918,
#  'far': 919,
#  'credit': 920,
#  'warren': 921,
#  '80': 922,
#  'figure': 923,
#  'block': 924,
#  'clifford': 925,
#  'zach': 926,
#  'doc': 927,
#  'round': 928,
#  '79': 929,
#  'ninth': 930,
#  'whatever': 931,
#  '59': 932,
#  'committed': 933,
#  'contract': 934,
#  'tatum': 935,
#  'reached': 936,
#  'hold': 937,
#  'several': 938,
#  'anderson': 939,
#  'follow': 940,
#  'kanter': 941,
#  '500': 942,
#  'appeared': 943,
#  'teague': 944,
#  'comeback': 945,
#  'rudy': 946,
#  'running': 947,
#  'throughout': 948,
#  'bazemore': 949,
#  'entering': 950,
#  'forced': 951,
#  'opportunity': 952,
#  'adams': 953,
#  'jefferson': 954,
#  'opener': 955,
#  'smart': 956,
#  'redick': 957,
#  'hot': 958,
#  'portis': 959,
#  'opponent': 960,
#  'happen': 961,
#  'picked': 962,
#  'barton': 963,
#  'kyrie': 964,
#  'outside': 965,
#  'tony': 966,
#  'averaged': 967,
#  'trailing': 968,
#  'lose': 969,
#  '74': 970,
#  'fournier': 971,
#  'sent': 972,
#  'marcus': 973,
#  'jamal': 974,
#  'fight': 975,
#  'derrick': 976,
#  'holding': 977,
#  'outrebounded': 978,
#  'ben': 979,
#  'remained': 980,
#  'fox': 981,
#  'full': 982,
#  'strained': 983,
#  'miles': 984,
#  'carter': 985,
#  '61': 986,
#  'blake': 987,
#  'shy': 988,
#  'jump': 989,
#  'matchup': 990,
#  'twice': 991,
#  'drive': 992,
#  'giannis': 993,
#  'rozier': 994,
#  "hasn't": 995,
#  'steal': 996,
#  'list': 997,
#  'stephen': 998,
#  'mcmillan': 999,
#  'joerger': 1000,
#  ...}

# %%
train_articles = pd.read_csv('data/2017/2017_articles.csv')
box_scores = pd.read_csv('data/2017/2017_article_box.csv')
event_space = pd.read_csv('data/2017/2017_tuple_space.csv')

team_map = {'ATL' : 'Atlanta Hawks', 'BOS': 'Boston Celtics', 'BRK': 'Brooklyn Nets', 
			'CHO': 'Charlotte Hornets', 'CHI': 'Chicago Bulls', 'CLE': 'Cleveland Cavaliers',
			'DET': 'Detroit Pistons', 'IND': 'Indiana Pacers', 'MIA': 'Miami Heat',
			'MIL': 'Milwaukee Bucks', 'NYK': 'New York Knicks', 'ORL': 'Orlando Magic',
			'PHI': 'Philadelphia 76ers', 'TOR': 'Toronto Raptors', 'WAS': 'Washington Wizards',
			'DAL': 'Dallas Mavericks', 'DEN': 'Denver Nuggets', 'GSW': 'Golden State Warriors',
			'HOU': 'Houston Rockets', 'LAC': 'Los Angeles Clippers', 'LAL': 'Los Angeles Lakers',
			'MEM': 'Memphis Grizzlies', 'MIN': 'Minnesota Timberwolves', 'NOP': 'New Orleans Pelicans',
			'OKC': 'Oklahoma City Thunder', 'PHO': 'Phoenix Suns', 'POR': 'Portland Trail Blazers',
			'SAC': 'Sacramento Kings', 'SAS': 'San Antonio Spurs', 'UTA': 'Utah Jazz',
			'NJN': 'New Jersey Nets', 'SEA': 'Seattle SuperSonics', 'CHA': 'Charlotte Bobcats'}

inv_team_map = {v: k for k, v in team_map.items()}

# %%
import re, csv, operator
from word2number import w2n
from preprocess import str_to_tup, get_tuples

articles = train_articles['article']

#year = '2017'
years = []
for i in range(2017, 2018):
    years.append(str(i))
    

for year in years:
    file_write = 'data/{}/{}_labeled_events.csv'.format(year, year)
    outFile = open(file_write, 'w')
    label_writer = csv.writer(outFile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    label_writer.writerow(['event', 'label'])
    for idx in range(len(articles)):
        if idx % 100 == 0:
            print(year, idx)
        
        article = articles[idx]
        article = article.replace('-', ' ')
        capital_words = re.findall('([A-Z][a-z]+)', article)

        data = box_scores['box_score'][idx]
        bs_data = str_to_tup(data)
        names = set()
        for record in bs_data:
            if len(record) == 15:
                names.add(record[0])

        team_map_values = [v for k, v in team_map.items()]

        names_present = set()
        for word in capital_words:
            for full_name in names:
                player = full_name.split(',')
                if word in player:
                    if len(player) > 1:
                        names_present.add((full_name, word))
            for team_name in team_map_values:
                team_name_entities = team_name.split(" ")
                if word in team_name_entities:
                    names_present.add((inv_team_map[team_name], word))
                                
        sentences = set()
        for name in names_present:
            for match in re.finditer(name[1], article):
                start = match.start()
                sent_end = start
                while True:
                    sent_end += 1
                    if article[sent_end:sent_end+2] == '. ' or sent_end > len(article) - 1:
                        break

                sent_begin = start
                while True:
                    sent_begin -= 1
                    if article[sent_begin] == '.' or sent_begin == 0:
                        break

                sentences.add((name[0], article[sent_begin+2:sent_end+1]))
                
        all_events = []
        for (name, s) in sentences:
            sent_words = s.split()
            for word in sent_words:
                if word.isdigit():
                    all_events.append((name, int(word), s))
                else:
                    try:
                        number = w2n.word_to_num(word)
                        split = s.split(" ")
                        i = split.index(word)
                        if "scored" in split or "points" in split:
                            all_events.append((name, number, s))
                    except:
                        continue

        game_event_space = str_to_tup(event_space['tuples'][idx])
        game_event_space = [tuple(i) for i in game_event_space]

        for record in game_event_space:
            for event in all_events:
                found_event = False
                if record[0] == event[0] and str(event[1]) == record[2]:
                    found_event = True
                    should_write = parse_event_by_sentence(record[0], record[1], record[2], event[2])
                    if should_write:
                        label_writer.writerow((record, 1))
            if not found_event:
                random = int(3 * np.random.uniform(0.0, 1.0, 1))

                if random == 0:
                    label_writer.writerow((record, 0))

    outFile.close()
# Out:
# 2017 0
# ('James,LeBron', 'pts', '29')
# ('Rose,Derrick', 'pts', '14')
# ('Wade,Dwyane', 'fg', '3')
# ('Wade,Dwyane', 'pts', '8')
# ('Love,Kevin', 'pts', '15')
# ('CLE', 'pts', '102')
# ('Brown,Jaylen', 'pts', '25')
# ('Brown,Jaylen', 'ast', '0')
# ('Irving,Kyrie', 'pts', '22')
# ('Irving,Kyrie', 'ast', '10')
# ('Tatum,Jayson', 'pts', '14')
# ('Tatum,Jayson', 'trb', '10')
# ('BOS', 'pts', '99')
# ('Thompson,Klay', 'pts', '16')
# ('Durant,Kevin', 'pts', '20')
# ('Curry,Stephen', 'fg3', '3')
# ('Curry,Stephen', 'ft', '3')
# ('Curry,Stephen', 'pts', '22')
# ('Green,Draymond', 'trb', '11')
# ('Green,Draymond', 'ast', '13')
# ('Young,Nick', 'fg3', '6')
# ('Young,Nick', 'pts', '23')
# ('West,David', 'fg', '2')
# ('GSW', 'pts', '121')
# ('Ariza,Trevor', 'fg', '3')
# ('Harden,James', 'fg3', '4')
# ('Harden,James', 'pts', '27')
# ('Paul,Chris', 'fg', '2')
# ('Paul,Chris', 'fg', '2')
# ('Paul,Chris', 'pts', '4')
# ('Gordon,Eric', 'fg', '9')
# ('Gordon,Eric', 'pts', '24')
# ('Tucker,P.J.', 'fg3', '4')
# ('Tucker,P.J.', 'ft', '4')
# ('Tucker,P.J.', 'pts', '20')
# ('HOU', 'pts', '122')
# ('Wall,John', 'fg', '10')
# ('Wall,John', 'ft', '8')
# ('Wall,John', 'pts', '28')
# ('Wall,John', 'pts', '28')
# ('Wall,John', 'ast', '8')
# ('Beal,Bradley', 'pts', '25')
# ('Gortat,Marcin', 'pts', '16')
# ('Gortat,Marcin', 'trb', '17')
# ('WAS', 'pts', '120')
# ('Covington,Robert', 'fg3', '7')
# ('Covington,Robert', 'pts', '29')
# ('Bayless,Jerryd', 'pts', '13')
# ('Embiid,Joel', 'pts', '18')
# ('Embiid,Joel', 'trb', '13')
# ('PHI', 'pts', '115')
# ('Johnson,Stanley', 'fg', '0')
# ('Johnson,Stanley', 'fg3', '0')
# ('Harris,Tobias', 'pts', '27')
# ('Harris,Tobias', 'trb', '10')
# ('Jackson,Reggie', 'pts', '13')
# ('Jackson,Reggie', 'ast', '8')
# ('Galloway,Langston', 'pts', '16')
# ('Ellenson,Henry', 'pts', '13')
# ('DET', 'fg3', '9')
# ('DET', 'ft', '11')
# ('DET', 'pts', '102')
# ('Walker,Kemba', 'pts', '24')
# ('Howard,Dwight', 'pts', '10')
# ('Howard,Dwight', 'trb', '15')
# ('Zeller,Cody', 'pts', '8')
# ('Zeller,Cody', 'trb', '9')
# ('CHO', 'fg3', '9')
# ('CHO', 'pts', '90')
# ('CHO', 'tov', '17')
# ('Turner,Myles', 'ft', '4')
# ('Turner,Myles', 'pts', '21')
# ('Turner,Myles', 'trb', '14')
# ('Turner,Myles', 'blk', '4')
# ('Young,Thaddeus', 'pts', '17')
# ('Young,Thaddeus', 'trb', '11')
# ('Collison,Darren', 'pts', '21')
# ('Collison,Darren', 'ast', '11')
# ('Bogdanovic,Bojan', 'pts', '14')
# ('Oladipo,Victor', 'pts', '22')
# ('Joseph,Cory', 'pts', '11')
# ('Stephenson,Lance', 'pts', '16')
# ('Sabonis,Domantas', 'fg', '7')
# ('Sabonis,Domantas', 'pts', '16')
# ('Sabonis,Domantas', 'trb', '7')
# ('IND', 'pts', '140')
# ('IND', 'pts', '140')
# ('Carroll,DeMarre', 'pts', '10')
# ('Lin,Jeremy', 'fg', '5')
# ('Lin,Jeremy', 'ft', '7')
# ('Lin,Jeremy', 'pts', '18')
# ('Booker,Trevor', 'pts', '20')
# ('Booker,Trevor', 'trb', '10')
# ('Crabbe,Allen', 'pts', '12')
# ('BRK', 'fg3', '12')
# ('BRK', 'fg3', '12')
# ('BRK', 'ft', '29')
# ('BRK', 'pts', '131')
# ('BRK', 'orb', '11')
# ('Fournier,Evan', 'ft', '2')
# ('Fournier,Evan', 'pts', '23')
# ('Vucevic,Nikola', 'pts', '19')
# ('ORL', 'pts', '116')
# ('Waiters,Dion', 'ft', '0')
# ('Whiteside,Hassan', 'pts', '26')
# ('Whiteside,Hassan', 'trb', '22')
# ('Olynyk,Kelly', 'pts', '10')
# ('Johnson,Tyler', 'ft', '0')
# ('Johnson,James', 'fg3', '0')
# ('Johnson,James', 'pts', '11')
# ('MIA', 'pts', '109')
# ('Irving,Kyrie', 'fg', '7')
# ('Irving,Kyrie', 'pts', '17')
# ('Tatum,Jayson', 'fg', '3')
# ('Tatum,Jayson', 'fg', '3')
# ('Tatum,Jayson', 'pts', '8')
# ('Tatum,Jayson', 'trb', '9')
# ('Brown,Jaylen', 'pts', '18')
# ('BOS', 'fg3', '11')
# ('BOS', 'ft', '11')
# ('BOS', 'pts', '100')
# ('Middleton,Khris', 'pts', '15')
# ('Middleton,Khris', 'trb', '9')
# ('Brogdon,Malcolm', 'pts', '19')
# ('Antetokounmpo,Giannis', 'fg', '13')
# ('Antetokounmpo,Giannis', 'pts', '37')
# ('Antetokounmpo,Giannis', 'pts', '37')
# ('Antetokounmpo,Giannis', 'trb', '13')
# ('Dellavedova,Matthew', 'fg3', '2')
# ('Dellavedova,Matthew', 'pts', '15')
# ('MIL', 'pts', '108')
# ('Conley,Mike', 'pts', '27')
# ('Gasol,Marc', 'pts', '14')
# ('Gasol,Marc', 'trb', '11')
# ('Brooks,Dillon', 'fg', '7')
# ('Brooks,Dillon', 'pts', '19')
# ('MEM', 'pts', '103')
# ('Davis,Anthony', 'pts', '33')
# ('Davis,Anthony', 'trb', '18')
# ('Cousins,DeMarcus', 'pts', '28')
# ('Cousins,DeMarcus', 'trb', '10')
# ('NOP', 'pts', '91')
# ('Barnes,Harrison', 'fg', '3')
# ('Barnes,Harrison', 'pts', '14')
# ('Matthews,Wesley', 'pts', '15')
# ('Smith,Dennis', 'fg', '6')
# ('Smith,Dennis', 'pts', '16')
# ('Smith,Dennis', 'pts', '16')
# ('Smith,Dennis', 'ast', '10')
# ('Nowitzki,Dirk', 'fg', '4')
# ('Nowitzki,Dirk', 'pts', '10')
# ('Noel,Nerlens', 'pts', '16')
# ('Noel,Nerlens', 'trb', '11')
# ('Harris,Devin', 'pts', '10')
# ('Powell,Dwight', 'pts', '6')
# ('DAL', 'pts', '111')
# ('Schroder,Dennis', 'fg', '13')
# ('Schroder,Dennis', 'pts', '28')
# ('Belinelli,Marco', 'fg3', '4')
# ('Belinelli,Marco', 'pts', '20')
# ('Collins,John', 'pts', '14')
# ('ATL', 'pts', '117')
# ('Gobert,Rudy', 'pts', '18')
# ('Gobert,Rudy', 'trb', '10')
# ('Rubio,Ricky', 'ast', '10')
# ('Favors,Derrick', 'pts', '14')
# ('Burks,Alec', 'pts', '16')
# ('UTA', 'pts', '106')
# ('Jokic,Nikola', 'trb', '12')
# ('Barton,Will', 'pts', '23')
# ('DEN', 'fg3', '13')
# ('DEN', 'pts', '96')
# ('Aldridge,LaMarcus', 'pts', '25')
# ('Aldridge,LaMarcus', 'trb', '10')
# ('Green,Danny', 'fg', '7')
# ('Green,Danny', 'fg3', '3')
# ('Green,Danny', 'fg3', '3')
# ('Green,Danny', 'fg3', '3')
# ('Green,Danny', 'pts', '17')
# ('Murray,Dejounte', 'fg', '7')
# ('Murray,Dejounte', 'pts', '16')
# ('Gay,Rudy', 'fg', '5')
# ('Gay,Rudy', 'ft', '4')
# ('Gay,Rudy', 'pts', '14')
# ('Gay,Rudy', 'trb', '5')
# ('Ginobili,Manu', 'ft', '4')
# ('Ginobili,Manu', 'pts', '9')
# ('Ginobili,Manu', 'ast', '4')
# ('SAS', 'pts', '107')
# ('Butler,Jimmy', 'pts', '12')
# ('Wiggins,Andrew', 'pts', '26')
# ('MIN', 'pts', '99')
# ('Bledsoe,Eric', 'fg', '5')
# ('Bledsoe,Eric', 'fg3', '1')
# ('Bledsoe,Eric', 'pts', '15')
# ('Bledsoe,Eric', 'pts', '15')
# ('Booker,Devin', 'fg', '6')
# ('Booker,Devin', 'fg', '6')
# ('Booker,Devin', 'fg3', '0')
# ('Booker,Devin', 'ft', '0')
# ('Booker,Devin', 'pts', '12')
# ('Chriss,Marquese', 'fg', '1')
# ('PHO', 'fg3', '7')
# ('PHO', 'fg3', '7')
# ('PHO', 'pts', '76')
# ('Lillard,Damian', 'fg3', '4')
# ('Lillard,Damian', 'ft', '3')
# ('Lillard,Damian', 'pts', '27')
# ('Connaughton,Pat', 'fg3', '4')
# ('Connaughton,Pat', 'pts', '24')
# ('POR', 'fg', '44')
# ('POR', 'fg3', '14')
# ('POR', 'pts', '124')
# ('Hield,Buddy', 'fg3', '3')
# ('Hield,Buddy', 'pts', '19')
# ('Hill,George', 'fg', '6')
# ('Hill,George', 'pts', '16')
# ('Carter,Vince', 'pts', '6')
# ('SAC', 'pts', '100')
# ('Harden,James', 'pts', '27')
# ('Harden,James', 'ast', '9')
# ('Gordon,Eric', 'fg3', '4')
# ('Gordon,Eric', 'pts', '25')
# ('Gordon,Eric', 'pts', '25')
# ('Ariza,Trevor', 'fg', '0')
# ('Ariza,Trevor', 'fg3', '0')
# ('Ariza,Trevor', 'ft', '2')
# ('Ariza,Trevor', 'pts', '2')
# ('Capela,Clint', 'pts', '22')
# ('Capela,Clint', 'trb', '17')
# ('Tucker,P.J.', 'pts', '6')
# ('HOU', 'fg', '33')
# ('HOU', 'ft', '27')
# ('HOU', 'pts', '105')
# ('Valanciunas,Jonas', 'pts', '23')
# ('Valanciunas,Jonas', 'trb', '15')
# ('Powell,Norman', 'pts', '15')
# ('Miles,C.J.', 'fg3', '6')
# ('Miles,C.J.', 'pts', '22')
# ('Anunoby,OG', 'pts', '9')
# ('TOR', 'fg', '39')
# ('TOR', 'fg3', '13')
# ('TOR', 'ft', '26')
# ('TOR', 'pts', '117')
# ('TOR', 'ast', '26')
# ('Markkanen,Lauri', 'pts', '17')
# ('Markkanen,Lauri', 'trb', '8')
# ('Lopez,Robin', 'pts', '18')
# ('Lopez,Robin', 'trb', '8')
# ('CHI', 'fg3', '10')
# ('George,Paul', 'pts', '28')
# ('Anthony,Carmelo', 'pts', '22')
# ('Johnson,Dakari', 'pts', '4')
# ('OKC', 'ft', '16')
# ('OKC', 'pts', '105')
# ('Porzingis,Kristaps', 'pts', '31')
# ('Porzingis,Kristaps', 'trb', '12')
# ('Kanter,Enes', 'pts', '10')
# ('Kanter,Enes', 'trb', '7')
# ('NYK', 'fg3', '7')
# ('NYK', 'pts', '84')
# ('Ball,Lonzo', 'fg', '1')
# ('Ball,Lonzo', 'fg3', '1')
# ('Ball,Lonzo', 'pts', '3')
# ('Lopez,Brook', 'pts', '20')
# ('Kuzma,Kyle', 'pts', '8')
# ('LAL', 'ft', '14')
# ('LAL', 'pts', '92')
# ('Griffin,Blake', 'pts', '29')
# ('Gallinari,Danilo', 'pts', '11')
# ('Jordan,DeAndre', 'pts', '14')
# ('Jordan,DeAndre', 'trb', '24')
# ('Beverley,Patrick', 'pts', '10')
# ('Williams,Lou', 'pts', '12')
# ('LAC', 'fg3', '12')
# ('LAC', 'ft', '12')
# ('LAC', 'pts', '108')
# ('Antetokounmpo,Giannis', 'fg', '15')
# ('Antetokounmpo,Giannis', 'pts', '34')
# ('Antetokounmpo,Giannis', 'trb', '8')
# ('Antetokounmpo,Giannis', 'trb', '8')
# ('Antetokounmpo,Giannis', 'ast', '8')
# ('Antetokounmpo,Giannis', 'ast', '8')
# ('Brogdon,Malcolm', 'pts', '16')
# ('Snell,Tony', 'fg', '3')
# ('Snell,Tony', 'fg', '3')
# ('Snell,Tony', 'fg3', '3')
# ('Snell,Tony', 'fg3', '3')
# ('MIL', 'fg3', '11')
# ('MIL', 'ft', '10')
# ('MIL', 'pts', '97')
# ('MIL', 'orb', '8')
# ('MIL', 'orb', '8')
# ('MIL', 'orb', '8')
# ('James,LeBron', 'pts', '24')
# ('James,LeBron', 'ast', '8')
# ('Love,Kevin', 'pts', '17')
# ('Love,Kevin', 'trb', '12')
# ('Korver,Kyle', 'fg', '6')
# ('Korver,Kyle', 'fg3', '5')
# ('Korver,Kyle', 'fg3', '5')
# ('Korver,Kyle', 'ft', '0')
# ('Korver,Kyle', 'pts', '17')
# ('Korver,Kyle', 'pts', '17')
# ('Korver,Kyle', 'trb', '3')
# ('CLE', 'fg3', '11')
# ('CLE', 'ft', '17')
# ('CLE', 'pts', '116')
# ('Walker,Kemba', 'pts', '26')
# ('Howard,Dwight', 'ft', '4')
# ('Howard,Dwight', 'pts', '20')
# ('Howard,Dwight', 'trb', '15')
# ('Bacon,Dwayne', 'trb', '11')
# ('Kaminsky,Frank', 'pts', '21')
# ('CHO', 'fg3', '11')
# ('CHO', 'ft', '24')
# ('CHO', 'ft', '24')
# ('CHO', 'pts', '109')
# ('Schroder,Dennis', 'pts', '25')
# ('Oladipo,Victor', 'pts', '17')
# ('Collison,Darren', 'pts', '14')
# ('Leaf,T.J.', 'pts', '17')
# ('Lillard,Damian', 'pts', '18')
# ('Turner,Evan', 'pts', '17')
# ('POR', 'pts', '114')
# ('Redick,J.J.', 'pts', '19')
# ('Embiid,Joel', 'fg', '4')
# ('Embiid,Joel', 'fg3', '0')
# ('Embiid,Joel', 'pts', '11')
# ('Embiid,Joel', 'pts', '11')
# ('PHI', 'pts', '92')
# ('Horford,Al', 'pts', '17')
# ('Irving,Kyrie', 'pts', '21')
# ('Tatum,Jayson', 'pts', '15')
# ('Rozier,Terry', 'pts', '14')
# ('BOS', 'pts', '102')
# ('Porter,Otto', 'pts', '28')
# ('Beal,Bradley', 'pts', '25')
# ('Wall,John', 'pts', '26')
# ('Wall,John', 'ast', '10')
# ('WAS', 'pts', '115')
# ('Bradley,Avery', 'fg3', '3')
# ('Bradley,Avery', 'ft', '3')
# ('Bradley,Avery', 'pts', '18')
# ('Jackson,Reggie', 'pts', '21')
# ('Drummond,Andre', 'pts', '9')
# ('Drummond,Andre', 'trb', '12')
# ('DET', 'pts', '111')
# ('Carroll,DeMarre', 'pts', '17')
# ('Booker,Trevor', 'pts', '17')
# ('Booker,Trevor', 'trb', '11')
# ('BRK', 'fg3', '9')
# ('BRK', 'pts', '126')
# ('Fournier,Evan', 'fg3', '2')
# ('Fournier,Evan', 'pts', '22')
# ('Fournier,Evan', 'orb', '2')
# ('Fournier,Evan', 'trb', '9')
# ('Vucevic,Nikola', 'pts', '41')
# ('Vucevic,Nikola', 'trb', '12')
# ('Butler,Jimmy', 'pts', '13')
# ('Butler,Jimmy', 'trb', '7')
# ('Wiggins,Andrew', 'pts', '21')
# ('Teague,Jeff', 'fg', '3')
# ('Teague,Jeff', 'fg', '3')
# ('Teague,Jeff', 'fg3', '0')
# ('Teague,Jeff', 'ft', '4')
# ('Teague,Jeff', 'pts', '10')
# ('Teague,Jeff', 'pts', '10')
# ('Teague,Jeff', 'ast', '4')
# ('Towns,Karl-Anthony', 'pts', '20')
# ('Towns,Karl-Anthony', 'trb', '10')
# ('Crawford,Jamal', 'fg3', '3')
# ('Crawford,Jamal', 'fg3', '3')
# ('Crawford,Jamal', 'pts', '17')
# ('Bjelica,Nemanja', 'pts', '10')
# ('Bjelica,Nemanja', 'trb', '5')
# ('MIN', 'ft', '21')
# ('MIN', 'pts', '100')
# ('MIN', 'orb', '10')
# ('MIN', 'orb', '10')
# ('Gobert,Rudy', 'pts', '10')
# ('Rubio,Ricky', 'ft', '10')
# ('Rubio,Ricky', 'ft', '10')
# ('Rubio,Ricky', 'ft', '10')
# ('Rubio,Ricky', 'pts', '19')
# ('Rubio,Ricky', 'ast', '10')
# ('Favors,Derrick', 'pts', '16')
# ('Hood,Rodney', 'pts', '20')
# ('UTA', 'pts', '97')
# ('Barnes,Harrison', 'pts', '24')
# ('Nowitzki,Dirk', 'pts', '10')
# ('Barea,J.J.', 'ft', '0')
# ('Barea,J.J.', 'pts', '9')
# ('Barea,J.J.', 'ast', '10')
# ('Ferrell,Yogi', 'pts', '14')
# ('DAL', 'pts', '88')
# ('DAL', 'pts', '88')
# ('Hill,George', 'fg3', '3')
# ('Hill,George', 'fg3', '3')
# ('Hill,George', 'fg3', '3')
# ('Hill,George', 'pts', '21')
# ('Randolph,Zach', 'pts', '13')
# ('Hield,Buddy', 'pts', '13')
# ('Carter,Vince', 'pts', '6')
# ('SAC', 'fg3', '10')
# ('SAC', 'ft', '9')
# ('SAC', 'pts', '93')
# ('Davis,Anthony', 'fg', '15')
# ('Davis,Anthony', 'pts', '35')
# ('Davis,Anthony', 'pts', '35')
# ('Holiday,Jrue', 'pts', '13')
# ('Cousins,DeMarcus', 'fg3', '3')
# ('Cousins,DeMarcus', 'fg3', '3')
# ('Cousins,DeMarcus', 'ft', '10')
# ('Cousins,DeMarcus', 'pts', '35')
# ('Cousins,DeMarcus', 'pts', '35')
# ('Cousins,DeMarcus', 'trb', '14')
# ('Clark,Ian', 'pts', '14')
# ('Crawford,Jordan', 'pts', '13')
# ('NOP', 'ft', '14')
# ('NOP', 'ft', '14')
# ('NOP', 'ft', '14')
# ('NOP', 'pts', '120')
# ('Durant,Kevin', 'fg3', '3')
# ('Durant,Kevin', 'ft', '1')
# ('Durant,Kevin', 'pts', '22')
# ('Thompson,Klay', 'fg3', '7')
# ('Thompson,Klay', 'ft', '0')
# ('Curry,Stephen', 'pts', '28')
# ('GSW', 'pts', '128')
# ('Booker,Devin', 'ft', '3')
# ('Booker,Devin', 'pts', '25')
# ('Booker,Devin', 'trb', '11')
# ('Warren,T.J.', 'ft', '5')
# ('Warren,T.J.', 'pts', '24')
# ('Bledsoe,Eric', 'fg3', '3')
# ('PHO', 'pts', '130')
# ('Ingram,Brandon', 'pts', '25')
# ('Lopez,Brook', 'fg3', '2')
# ('LAL', 'pts', '132')
# ('Lowry,Kyle', 'pts', '17')
# ('Lowry,Kyle', 'pts', '17')
# ('Ibaka,Serge', 'ft', '2')
# ('Ibaka,Serge', 'pts', '21')
# ('Poeltl,Jakob', 'pts', '14')
# ('TOR', 'fg3', '13')
# ('TOR', 'ft', '31')
# ('TOR', 'pts', '128')
# ('Simmons,Ben', 'pts', '18')
# ('Simmons,Ben', 'trb', '10')
# ('Simmons,Ben', 'trb', '10')
# ('Simmons,Ben', 'trb', '10')
# ('Bayless,Jerryd', 'pts', '16')
# ('Okafor,Jahlil', 'pts', '10')
# ('Anderson,Justin', 'pts', '12')
# ('PHI', 'fg', '32')
# ('PHI', 'pts', '94')
# ('PHI', 'tov', '20')
# ('James,LeBron', 'pts', '22')
# ('Shumpert,Iman', 'pts', '21')
# ('CLE', 'fg3', '7')
# ('CLE', 'pts', '93')
# ('Vucevic,Nikola', 'fg', '11')
# ('Vucevic,Nikola', 'ft', '0')
# ('Vucevic,Nikola', 'pts', '23')
# ('Augustin,D.J.', 'fg3', '3')
# ('Augustin,D.J.', 'pts', '12')
# ('Fournier,Evan', 'pts', '13')
# ('Simmons,Jonathon', 'pts', '19')
# ('ORL', 'fg3', '17')
# ('ORL', 'fg3', '17')
# ('ORL', 'ft', '17')
# ('ORL', 'ft', '17')
# ('ORL', 'pts', '114')
# ('Richardson,Josh', 'fg3', '3')
# ('Richardson,Josh', 'pts', '12')
# ('Waiters,Dion', 'pts', '19')
# ('Dragic,Goran', 'ft', '3')
# ('Dragic,Goran', 'pts', '23')
# ('Johnson,James', 'pts', '14')
# ('Olynyk,Kelly', 'fg3', '3')
# ('Olynyk,Kelly', 'ft', '0')
# ('Olynyk,Kelly', 'pts', '13')
# ('Olynyk,Kelly', 'pts', '13')
# ('MIA', 'fg3', '14')
# ('MIA', 'fg3', '14')
# ('MIA', 'ft', '8')
# ('MIA', 'pts', '112')
# ('Oladipo,Victor', 'pts', '28')
# ('Young,Thaddeus', 'pts', '14')
# ('Sabonis,Domantas', 'pts', '18')
# ('Jefferson,Al', 'pts', '14')
# ('Jefferson,Al', 'pts', '14')
# ('IND', 'pts', '108')
# ('Porzingis,Kristaps', 'pts', '33')
# ('Kanter,Enes', 'pts', '17')
# ('Kanter,Enes', 'trb', '10')
# ('NYK', 'fg', '37')
# ('NYK', 'pts', '107')
# ('Harris,Tobias', 'ft', '2')
# ('Harris,Tobias', 'ft', '2')
# ('Harris,Tobias', 'pts', '31')
# ('Drummond,Andre', 'ft', '3')
# ('Drummond,Andre', 'ft', '3')
# ('Drummond,Andre', 'pts', '21')
# ('Drummond,Andre', 'trb', '12')
# ('Tolliver,Anthony', 'ft', '0')
# ('DET', 'pts', '111')
# ('DET', 'pts', '111')
# ('Markkanen,Lauri', 'pts', '13')
# ('Markkanen,Lauri', 'trb', '12')
# ('Holiday,Justin', 'fg', '5')
# ('Holiday,Justin', 'pts', '15')
# ('Lopez,Robin', 'fg', '7')
# ('Lopez,Robin', 'pts', '16')
# ('Lopez,Robin', 'trb', '7')
# ('CHI', 'pts', '77')
# ('Aldridge,LaMarcus', 'fg', '12')
# ('Aldridge,LaMarcus', 'pts', '28')
# ('Aldridge,LaMarcus', 'trb', '10')
# ('Gay,Rudy', 'pts', '12')
# ('Gay,Rudy', 'pts', '12')
# ('SAS', 'ft', '10')
# ('SAS', 'pts', '87')
# ('Harden,James', 'ft', '3')
# ('Harden,James', 'pts', '29')
# ('Harden,James', 'pts', '29')
# ('Gordon,Eric', 'pts', '18')
# ('Gordon,Eric', 'pts', '18')
# ('Capela,Clint', 'pts', '13')
# ('Capela,Clint', 'trb', '10')
# ('Jackson,Demetrius', 'pts', '4')
# ('Hilario,Nene', 'pts', '14')
# ('HOU', 'fg', '39')
# ('HOU', 'fg3', '11')
# ('HOU', 'fg3', '11')
# ('HOU', 'ft', '18')
# ('HOU', 'ft', '18')
# ('HOU', 'pts', '107')
# ('Barnes,Harrison', 'pts', '14')
# ('Nowitzki,Dirk', 'fg', '1')
# ('Nowitzki,Dirk', 'pts', '2')
# ('Barea,J.J.', 'pts', '19')
# ('DAL', 'pts', '91')
# ('Gasol,Marc', 'pts', '34')
# ('Gasol,Marc', 'trb', '14')
# ('Ennis,James', 'pts', '13')
# ('Evans,Tyreke', 'pts', '12')
# ('MEM', 'fg3', '10')
# ('MEM', 'pts', '111')
# ('MEM', 'ast', '20')
# ('MEM', 'ast', '20')
# ('Durant,Kevin', 'pts', '29')
# ('Durant,Kevin', 'trb', '13')
# ('Curry,Stephen', 'ft', '13')
# ('Curry,Stephen', 'pts', '37')
# ('GSW', 'fg3', '12')
# ('GSW', 'fg3', '12')
# ('GSW', 'pts', '101')
# ('GSW', 'ast', '20')
# ('GSW', 'ast', '20')
# ('Antetokounmpo,Giannis', 'fg', '17')
# ('Antetokounmpo,Giannis', 'fg', '17')
# ('Antetokounmpo,Giannis', 'pts', '44')
# ('Snell,Tony', 'pts', '17')
# ('MIL', 'fg3', '7')
# ('MIL', 'ft', '22')
# ('Lillard,Damian', 'fg3', '3')
# ('Lillard,Damian', 'pts', '26')
# ('Nurkic,Jusuf', 'fg', '7')
# ('Nurkic,Jusuf', 'pts', '17')
# ('Nurkic,Jusuf', 'trb', '11')
# ('POR', 'fg3', '11')
# ('POR', 'pts', '110')
# ('Harris,Gary', 'fg', '7')
# ('Harris,Gary', 'ft', '0')
# ('Harris,Gary', 'pts', '17')
# ('Chandler,Wilson', 'trb', '12')
# ('Millsap,Paul', 'pts', '18')
# ('Millsap,Paul', 'trb', '9')
# ('Barton,Will', 'ft', '0')
# ('Barton,Will', 'pts', '15')
# ('Barton,Will', 'orb', '1')
# ('Barton,Will', 'trb', '5')
# ('Faried,Kenneth', 'pts', '18')
# ('Faried,Kenneth', 'trb', '8')
# ('DEN', 'ft', '12')
# ('DEN', 'pts', '96')
# ('DEN', 'orb', '18')
# ('DEN', 'orb', '18')
# ('Cauley-Stein,Willie', 'fg', '1')
# ('Cauley-Stein,Willie', 'pts', '2')
# ('Cauley-Stein,Willie', 'orb', '1')
# ('SAC', 'ft', '9')
# ('SAC', 'ft', '9')
# ('SAC', 'pts', '79')
# ('Rubio,Ricky', 'pts', '16')
# ('Gobert,Rudy', 'pts', '16')
# ('Gobert,Rudy', 'trb', '13')
# ('Ingles,Joe', 'fg3', '5')
# ('Favors,Derrick', 'ft', '5')
# ('Favors,Derrick', 'pts', '13')
# ('UTA', 'fg', '38')
# ('UTA', 'pts', '96')
# ('George,Paul', 'fg3', '3')
# ('George,Paul', 'ft', '3')
# ('Anthony,Carmelo', 'fg3', '2')
# ('Anthony,Carmelo', 'pts', '26')
# ('Westbrook,Russell', 'fg', '2')
# ('Westbrook,Russell', 'pts', '6')
# ('Westbrook,Russell', 'orb', '2')
# ('Westbrook,Russell', 'trb', '13')
# ('Westbrook,Russell', 'ast', '9')
# ('OKC', 'pts', '87')
# ('Gallinari,Danilo', 'fg3', '3')
# ('Griffin,Blake', 'pts', '29')
# ('Griffin,Blake', 'trb', '8')
# ('Beverley,Patrick', 'fg', '6')
# ('Beverley,Patrick', 'pts', '15')
# ('LAC', 'pts', '130')
# ('Booker,Devin', 'pts', '13')
# ('Jackson,Josh', 'fg3', '2')
# ('Jackson,Josh', 'pts', '12')
# ('Len,Alex', 'pts', '15')
# ('PHO', 'fg3', '6')
# ('PHO', 'pts', '88')
# ('PHO', 'stl', '8')
# ('LeVert,Caris', 'pts', '16')
# ('Carroll,DeMarre', 'fg3', '2')
# ('Crabbe,Allen', 'pts', '20')
# ('BRK', 'pts', '116')
# ('Schroder,Dennis', 'fg3', '0')
# ('Schroder,Dennis', 'fg3', '0')
# ('Belinelli,Marco', 'fg3', '3')
# ('Belinelli,Marco', 'pts', '19')
# ('Anthony,Carmelo', 'ft', '3')
# ('Anthony,Carmelo', 'pts', '23')
# ('Westbrook,Russell', 'pts', '31')
# ('Adams,Steven', 'fg', '8')
# ('Adams,Steven', 'pts', '17')
# ('Adams,Steven', 'trb', '13')
# ('Grant,Jerami', 'pts', '12')
# ('Felton,Raymond', 'pts', '12')
# ('OKC', 'fg3', '11')
# ('OKC', 'ft', '10')
# ('OKC', 'pts', '113')
# ('Wiggins,Andrew', 'fg', '10')
# ('Wiggins,Andrew', 'pts', '27')
# ('Wiggins,Andrew', 'pts', '27')
# ('Teague,Jeff', 'pts', '19')
# ('Towns,Karl-Anthony', 'pts', '27')
# ('Towns,Karl-Anthony', 'pts', '27')
# ('Towns,Karl-Anthony', 'trb', '12')
# ('Gibson,Taj', 'pts', '11')
# ('Gibson,Taj', 'trb', '10')
# ('MIN', 'fg3', '10')
# ('MIN', 'fg3', '10')
# ('MIN', 'pts', '115')
# ('MIN', 'orb', '10')
# ('Ball,Lonzo', 'ast', '13')
# ('Caldwell-Pope,Kentavious', 'pts', '20')
# ('Kuzma,Kyle', 'ft', '4')
# ('Kuzma,Kyle', 'pts', '20')
# ('Clarkson,Jordan', 'pts', '24')
# ('LAL', 'pts', '112')
# ('Davis,Anthony', 'pts', '27')
# ('Davis,Anthony', 'trb', '17')
# ('Cousins,DeMarcus', 'pts', '22')
# ('Cousins,DeMarcus', 'trb', '11')
# ('Drummond,Andre', 'fg3', '0')
# ('Drummond,Andre', 'pts', '14')
# ('Drummond,Andre', 'pts', '14')
# ('Drummond,Andre', 'trb', '14')
# ('Drummond,Andre', 'trb', '14')
# ('Jackson,Reggie', 'fg', '7')
# ('Jackson,Reggie', 'pts', '16')
# ('Jackson,Reggie', 'ast', '7')
# ('DET', 'fg3', '6')
# ('DET', 'ft', '14')
# ('DET', 'ft', '14')
# ('DET', 'pts', '86')
# ('Covington,Robert', 'fg3', '3')
# ('Simmons,Ben', 'pts', '21')
# ('Simmons,Ben', 'trb', '12')
# ('Simmons,Ben', 'ast', '10')
# ('Embiid,Joel', 'pts', '30')
# ('Richardson,Josh', 'fg', '8')
# ('Richardson,Josh', 'fg3', '3')
# ('Richardson,Josh', 'pts', '21')
# ('Richardson,Josh', 'pts', '21')
# ('Dragic,Goran', 'ft', '3')
# ('Dragic,Goran', 'ft', '3')
# ('Dragic,Goran', 'pts', '19')
# ('Johnson,Tyler', 'fg', '1')
# ('Ellington,Wayne', 'fg', '6')
# ('Ellington,Wayne', 'fg3', '6')
# ('Ellington,Wayne', 'pts', '20')
# ('MIA', 'fg3', '14')
# ('MIA', 'ft', '12')
# ('MIA', 'ft', '12')
# ('MIA', 'ft', '12')
# ('MIA', 'ft', '12')
# ('MIA', 'pts', '104')
# ('Waller-Prince,Taurean', 'pts', '20')
# ('Bazemore,Kent', 'ft', '7')
# ('Bazemore,Kent', 'pts', '20')
# ('Collins,John', 'pts', '14')
# ('Collins,John', 'trb', '11')
# ('ATL', 'fg3', '7')
# ('ATL', 'ft', '14')
# ('ATL', 'pts', '93')
# ('Harden,James', 'pts', '22')
# ('Gordon,Eric', 'pts', '27')
# ('HOU', 'pts', '90')
# ('HOU', 'pts', '90')
# ('Gasol,Marc', 'ft', '10')
# ('Gasol,Marc', 'ft', '10')
# ('Gasol,Marc', 'pts', '26')
# ('Conley,Mike', 'fg', '3')
# ('Conley,Mike', 'fg', '3')
# ('Conley,Mike', 'ft', '9')
# ('Conley,Mike', 'pts', '17')
# ('MEM', 'fg3', '6')
# ('Antetokounmpo,Giannis', 'pts', '32')
# ('Antetokounmpo,Giannis', 'trb', '14')
# ('Middleton,Khris', 'ft', '3')
# ('Middleton,Khris', 'ft', '3')
# ('Middleton,Khris', 'pts', '20')
# ('MIL', 'fg3', '9')
# ('MIL', 'ft', '14')
# ('MIL', 'pts', '103')
# ('Walker,Kemba', 'pts', '15')
# ('Howard,Dwight', 'fg3', '0')
# ('Howard,Dwight', 'ft', '0')
# ('Howard,Dwight', 'trb', '22')
# ('Lamb,Jeremy', 'pts', '17')
# ('Kaminsky,Frank', 'fg3', '3')
# ('Kaminsky,Frank', 'ft', '3')
# ('Kaminsky,Frank', 'pts', '18')
# ('CHO', 'fg', '33')
# ('CHO', 'pts', '94')
# ('CHO', 'pts', '94')
# ('Matthews,Wesley', 'fg3', '3')
# ('Matthews,Wesley', 'pts', '19')
# ('Barnes,Harrison', 'pts', '13')
# ('DAL', 'pts', '103')
# ('Durant,Kevin', 'fg', '9')
# ('Durant,Kevin', 'fg3', '4')
# ('Durant,Kevin', 'pts', '25')
# ('Curry,Stephen', 'fg3', '2')
# ('Curry,Stephen', 'pts', '29')
# ('Green,Draymond', 'pts', '10')
# ('Green,Draymond', 'trb', '7')
# ('Thompson,Klay', 'fg3', '3')
# ('Thompson,Klay', 'ft', '0')
# ('Thompson,Klay', 'pts', '21')
# ('GSW', 'fg3', '15')
# ('GSW', 'pts', '133')
# ('Aldridge,LaMarcus', 'pts', '20')
# ('Aldridge,LaMarcus', 'pts', '20')
# ('Green,Danny', 'pts', '17')
# ('Murray,Dejounte', 'pts', '16')
# ('SAS', 'ft', '16')
# ('SAS', 'pts', '101')
# ('SAS', 'blk', '12')
# ('SAS', 'tov', '20')
# ('Ibaka,Serge', 'pts', '13')
# ('TOR', 'pts', '97')
# ('Jokic,Nikola', 'pts', '29')
# ('Millsap,Paul', 'pts', '17')
# ('Mudiay,Emmanuel', 'pts', '15')
# ('Beal,Bradley', 'pts', '20')
# ('Wall,John', 'pts', '19')
# ('WAS', 'ft', '26')
# ('WAS', 'pts', '109')
# ('Chriss,Marquese', 'pts', '19')
# ('Booker,Devin', 'fg3', '2')
# ('Booker,Devin', 'pts', '22')
# ('James,Mike', 'pts', '18')
# ('PHO', 'pts', '117')
# ('Bogdanovic,Bogdan', 'fg', '5')
# ('Bogdanovic,Bogdan', 'pts', '12')
# ('Temple,Garrett', 'pts', '23')
# ('SAC', 'pts', '115')
# ('James,LeBron', 'pts', '34')
# ('Crowder,Jae', 'fg3', '3')
# ('Crowder,Jae', 'fg3', '3')
# ('Love,Kevin', 'fg', '7')
# ('Love,Kevin', 'fg3', '3')
# ('Love,Kevin', 'ft', '3')
# ('Love,Kevin', 'pts', '20')
# ('Love,Kevin', 'trb', '12')
# ('Thompson,Tristan', 'ft', '1')
# ('Green,Jeff', 'pts', '16')
# ('Korver,Kyle', 'fg3', '3')
# ('Wade,Dwyane', 'pts', '11')
# ('Holiday,Justin', 'pts', '25')
# ('Markkanen,Lauri', 'fg', '7')
# ('Markkanen,Lauri', 'pts', '19')
# ('Lopez,Robin', 'fg3', '1')
# ('Felder,Kay', 'pts', '13')
# ('CHI', 'fg3', '17')
# ('CHI', 'pts', '112')
# ('Gordon,Aaron', 'fg', '14')
# ('Gordon,Aaron', 'fg', '14')
# ('Gordon,Aaron', 'fg3', '5')
# ('Gordon,Aaron', 'fg3', '5')
# ('Gordon,Aaron', 'pts', '41')
# ('Gordon,Aaron', 'trb', '14')
# ('Fournier,Evan', 'pts', '28')
# ('Vucevic,Nikola', 'fg', '6')
# ('Vucevic,Nikola', 'fg3', '0')
# ('Vucevic,Nikola', 'ft', '0')
# ('Vucevic,Nikola', 'pts', '12')
# ('ORL', 'fg', '41')
# ('ORL', 'pts', '125')
# ('ORL', 'ast', '20')
# ('BRK', 'ft', '30')
# ('BRK', 'pts', '121')
# ('Brown,Jaylen', 'ft', '2')
# ('Brown,Jaylen', 'pts', '23')
# ('Tatum,Jayson', 'pts', '22')
# ('Irving,Kyrie', 'pts', '20')
# ('Irving,Kyrie', 'ast', '7')
# ('Horford,Al', 'pts', '13')
# ('Horford,Al', 'pts', '13')
# ('Horford,Al', 'trb', '13')
# ('Horford,Al', 'trb', '13')
# ('BOS', 'pts', '110')
# ('Kanter,Enes', 'pts', '16')
# ('Kanter,Enes', 'pts', '16')
# ('Kanter,Enes', 'trb', '19')
# ('NYK', 'ft', '16')
# ('NYK', 'ft', '16')
# ('NYK', 'pts', '89')
# ('Wiggins,Andrew', 'ft', '1')
# ('Towns,Karl-Anthony', 'pts', '28')
# ('Towns,Karl-Anthony', 'trb', '7')
# ('Teague,Jeff', 'pts', '2')
# ('Teague,Jeff', 'ast', '7')
# ('MIN', 'fg3', '9')
# ('MIN', 'ft', '14')
# ('Collison,Darren', 'pts', '15')
# ('Collison,Darren', 'pts', '15')
# ('Collison,Darren', 'ast', '16')
# ('Bogdanovic,Bojan', 'fg', '9')
# ('Bogdanovic,Bojan', 'pts', '19')
# ('Oladipo,Victor', 'pts', '28')
# ('Sabonis,Domantas', 'pts', '15')
# ('Sabonis,Domantas', 'pts', '15')
# ('Sabonis,Domantas', 'trb', '11')
# ('Joseph,Cory', 'fg3', '5')
# ('Joseph,Cory', 'pts', '21')
# ('IND', 'ft', '8')
# ('IND', 'pts', '130')
# ('IND', 'ast', '31')
# ('Lillard,Damian', 'fg', '3')
# ('Lillard,Damian', 'fg', '3')
# ('Lillard,Damian', 'fg', '3')
# ('Lillard,Damian', 'fg3', '1')
# ('Lillard,Damian', 'fg3', '1')
# ('Lillard,Damian', 'pts', '13')
# ('Turner,Evan', 'fg3', '1')
# ('Turner,Evan', 'pts', '13')
# ('Davis,Ed', 'pts', '12')
# ('Davis,Ed', 'trb', '10')
# ('POR', 'fg3', '10')
# ('POR', 'pts', '103')
# ('Cousins,DeMarcus', 'pts', '39')
# ('Cousins,DeMarcus', 'trb', '13')
# ('NOP', 'pts', '93')
# ('Beverley,Patrick', 'pts', '19')
# ('Jordan,DeAndre', 'pts', '11')
# ('Jordan,DeAndre', 'trb', '18')
# ('Griffin,Blake', 'pts', '22')
# ('Rivers,Austin', 'pts', '16')
# ('LAC', 'pts', '102')
# ('Mitchell,Donovan', 'pts', '19')
# ('UTA', 'fg3', '7')
# ('Walker,Kemba', 'pts', '19')
# ('Walker,Kemba', 'ast', '5')
# ('Lamb,Jeremy', 'pts', '16')
# ('Howard,Dwight', 'ft', '7')
# ('Kaminsky,Frank', 'pts', '20')
# ('Monk,Malik', 'pts', '17')
# ('CHO', 'pts', '110')
# ('Jokic,Nikola', 'pts', '18')
# ('Plumlee,Mason', 'trb', '10')
# ('DEN', 'pts', '93')
# ('DEN', 'orb', '18')
# ('Harris,Tobias', 'fg3', '6')
# ('Harris,Tobias', 'pts', '34')
# ('Johnson,Stanley', 'pts', '15')
# ('Bradley,Avery', 'pts', '20')
# ('Drummond,Andre', 'pts', '15')
# ('Drummond,Andre', 'trb', '15')
# ('Smith,Ish', 'ast', '13')
# ('DET', 'fg3', '15')
# ('DET', 'pts', '122')
# ('DET', 'ast', '32')
# ('DET', 'tov', '14')
# ('Towns,Karl-Anthony', 'pts', '23')
# ('Towns,Karl-Anthony', 'trb', '10')
# ('MIN', 'fg3', '9')
# ('MIN', 'pts', '101')
# ('MIN', 'tov', '14')
# ('Covington,Robert', 'pts', '20')
# ('Redick,J.J.', 'pts', '22')
# ('Embiid,Joel', 'fg3', '1')
# ('Embiid,Joel', 'pts', '21')
# ('PHI', 'pts', '104')
# ('Harden,James', 'pts', '27')
# ('Gordon,Eric', 'pts', '29')
# ('Capela,Clint', 'pts', '16')
# ('Capela,Clint', 'trb', '20')
# ('HOU', 'fg3', '12')
# ('HOU', 'ft', '21')
# ('HOU', 'pts', '105')
# ('Hollis-Jefferson,Rondae', 'fg', '5')
# ('Hollis-Jefferson,Rondae', 'pts', '19')
# ('Carroll,DeMarre', 'pts', '18')
# ('Dinwiddie,Spencer', 'pts', '22')
# ('Crabbe,Allen', 'pts', '19')
# ('Allen,Jarrett', 'fg3', '0')
# ('Allen,Jarrett', 'ft', '0')
# ('Acy,Quincy', 'ft', '0')
# ('Acy,Quincy', 'pts', '3')
# ('Acy,Quincy', 'pts', '3')
# ('BRK', 'pts', '112')
# ('James,LeBron', 'pts', '29')
# ('James,LeBron', 'trb', '10')
# ('James,LeBron', 'ast', '13')
# ('Love,Kevin', 'fg', '4')
# ('Smith,J.R.', 'fg', '1')
# ('CLE', 'pts', '107')
# ('Johnson,James', 'pts', '21')
# ('Richardson,Josh', 'fg', '1')
# ('Johnson,Tyler', 'pts', '23')
# ('MIA', 'fg3', '9')
# ('Aldridge,LaMarcus', 'pts', '31')
# ('Aldridge,LaMarcus', 'pts', '31')
# ('Green,Danny', 'ft', '0')
# ('Anderson,Kyle', 'fg', '4')
# ('Anderson,Kyle', 'fg3', '0')
# ('Anderson,Kyle', 'ft', '4')
# ('Anderson,Kyle', 'pts', '12')
# ('Anderson,Kyle', 'trb', '10')
# ('Gasol,Pau', 'fg3', '0')
# ('Gasol,Pau', 'pts', '13')
# ('Gay,Rudy', 'ft', '9')
# ('Gay,Rudy', 'pts', '22')
# ('Ginobili,Manu', 'ft', '0')
# ('Ginobili,Manu', 'orb', '0')
# ('SAS', 'fg3', '10')
# ('SAS', 'fg3', '10')
# ('SAS', 'pts', '117')
# ('Westbrook,Russell', 'fg', '10')
# ('Westbrook,Russell', 'fg', '10')
# ('Westbrook,Russell', 'fg', '10')
# ('Westbrook,Russell', 'pts', '28')
# ('Westbrook,Russell', 'pts', '28')
# ('Westbrook,Russell', 'trb', '10')
# ('Westbrook,Russell', 'trb', '10')
# ('Westbrook,Russell', 'ast', '16')
# ('Anthony,Carmelo', 'pts', '28')
# ('Anthony,Carmelo', 'pts', '28')
# ('Anthony,Carmelo', 'trb', '10')
# ('Anthony,Carmelo', 'trb', '10')
# ('Adams,Steven', 'pts', '17')
# ('Adams,Steven', 'trb', '11')
# ('George,Paul', 'pts', '10')
# ('George,Paul', 'pts', '10')
# ('George,Paul', 'pts', '10')
# ('Huestis,Josh', 'pts', '3')
# ('OKC', 'fg3', '10')
# ('OKC', 'fg3', '10')
# ('OKC', 'fg3', '10')
# ('OKC', 'pts', '114')
# ('OKC', 'orb', '16')
# ('Collison,Darren', 'pts', '18')
# ('Oladipo,Victor', 'fg', '11')
# ('Oladipo,Victor', 'pts', '35')
# ('IND', 'pts', '96')
# ('Nowitzki,Dirk', 'pts', '13')
# ('Noel,Nerlens', 'pts', '8')
# ('DAL', 'ft', '20')
# ('DAL', 'pts', '103')
# ('Gasol,Marc', 'ft', '3')
# ('Gasol,Marc', 'pts', '26')
# ('Conley,Mike', 'pts', '21')
# ('Evans,Tyreke', 'pts', '13')
# ('MEM', 'ft', '16')
# ('MEM', 'ft', '16')
# ('MEM', 'pts', '94')
# ('MEM', 'trb', '36')
# ('Booker,Devin', 'fg3', '2')
# ('Booker,Devin', 'pts', '17')
# ('Warren,T.J.', 'fg3', '0')
# ('Warren,T.J.', 'pts', '27')
# ('Len,Alex', 'pts', '13')
# ('Len,Alex', 'pts', '13')
# ('Ulis,Tyler', 'fg', '6')
# ('Ulis,Tyler', 'pts', '13')
# ('Jackson,Josh', 'fg', '2')
# ('PHO', 'fg', '42')
# ('PHO', 'fg3', '6')
# ('PHO', 'pts', '97')
# ('Hood,Rodney', 'pts', '22')
# ('UTA', 'fg3', '6')
# ('UTA', 'fg3', '6')
# ('UTA', 'pts', '88')
# ('Thompson,Klay', 'fg', '9')
# ('Thompson,Klay', 'fg3', '4')
# ('Thompson,Klay', 'ft', '0')
# ('Thompson,Klay', 'pts', '22')
# ('Durant,Kevin', 'fg', '11')
# ('Durant,Kevin', 'fg3', '3')
# ('Durant,Kevin', 'fg3', '3')
# ('Durant,Kevin', 'fg3', '3')
# ('Durant,Kevin', 'ft', '4')
# ('Durant,Kevin', 'ft', '4')
# ('Durant,Kevin', 'pts', '29')
# ('Durant,Kevin', 'trb', '4')
# ('Curry,Stephen', 'fg3', '4')
# ('Curry,Stephen', 'pts', '30')
# ('Green,Draymond', 'pts', '15')
# ('Green,Draymond', 'trb', '11')
# ('GSW', 'pts', '117')
# ('GSW', 'tov', '17')
# ('Lowry,Kyle', 'pts', '14')
# ('Lowry,Kyle', 'ast', '9')
# ('Ibaka,Serge', 'pts', '15')
# ('Siakam,Pascal', 'pts', '20')
# ('Poeltl,Jakob', 'orb', '11')
# ('Poeltl,Jakob', 'trb', '14')
# ('TOR', 'pts', '112')
# ('Caldwell-Pope,Kentavious', 'fg3', '3')
# ('Ball,Lonzo', 'ast', '10')
# ('Ingram,Brandon', 'ft', '3')
# ('Ingram,Brandon', 'pts', '19')
# ('LAL', 'pts', '102')
# ('LAL', 'orb', '6')
# ('LAL', 'orb', '6')
# ('LAL', 'orb', '6')
# ('Beal,Bradley', 'ft', '4')
# ('Beal,Bradley', 'pts', '28')
# ('Wall,John', 'ft', '3')
# ('Wall,John', 'pts', '18')
# ('Wall,John', 'pts', '18')
# ('Smith,Jason', 'pts', '2')
# ('Smith,Jason', 'pts', '2')
# ('Smith,Jason', 'pts', '2')
# ('Smith,Jason', 'orb', '2')
# ('Smith,Jason', 'orb', '2')
# ('Smith,Jason', 'orb', '2')
# ('Smith,Jason', 'trb', '2')
# ('Smith,Jason', 'trb', '2')
# ('Smith,Jason', 'trb', '2')
# ('WAS', 'fg3', '6')
# ('WAS', 'fg3', '6')
# ('WAS', 'ft', '15')
# ('WAS', 'pts', '99')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3693c1076853> in <module>()
#      52                 while True:
#      53                     sent_end += 1
# ---> 54                     if article[sent_end:sent_end+2] == '. ' or sent_end > len(article) - 1:
#      55                         break
#      56
#
# KeyboardInterrupt:

# %%
def parse_event_by_sentence(name, cat, value, sent):
    if cat == 'ast' and 'assists' not in sent:
        return False
    if cat == 'stl' and 'steals' not in sent:
        return False
    if (cat == 'orb' or cat == 'trb') and ('rebounds' not in sent and 'boards' not in sent):
        return False
    if cat == 'tov' and 'turnovers' not in sent:
        return False
    if cat == 'blk' and 'blocks' not in sent:
        return False
    return True

def replace_sentence_with_tokens(record, sentence):
    name = record[0].split(',')
    stat_value = record[2]
    if len(name) == 2:
        last_name = name[0]
        first_name = name[1]
        sentence = sentence.replace(last_name, "PLAYER_LAST")
        sentence = sentence.replace(first_name, "PLAYER_FIRST")
        sentence = sentence.replace(stat_value, "STAT")
    else:
        sentence = sentence.replace(record[0], "TEAM")
        sentence.replace(stat_value, "STAT")

    return sentence

# %%
import re, csv, operator
from word2number import w2n
from preprocess import str_to_tup, get_tuples

articles = train_articles['article']

#year = '2017'
years = []
for i in range(2010, 2018):
    years.append(str(i))

for year in years:
    file_write = 'data/{}/{}_tuple_sentences.csv'.format(year, year)
    outFile = open(file_write, 'w', newline='')
    label_writer = csv.writer(outFile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    label_writer.writerow(['event', 'sentence'])
    for idx in range(len(articles)):
        if idx % 100 == 0:
            print(year, idx)
        
        article = articles[idx]
        article = article.replace('-', ' ')
        capital_words = re.findall('([A-Z][a-z]+)', article)

        data = box_scores['box_score'][idx]
        bs_data = str_to_tup(data)
        names = set()
        for record in bs_data:
            if len(record) == 15:
                names.add(record[0])

        team_map_values = [v for k, v in team_map.items()]

        names_present = set()
        for word in capital_words:
            for full_name in names:
                player = full_name.split(',')
                if word in player:
                    if len(player) > 1:
                        names_present.add((full_name, word))
            for team_name in team_map_values:
                team_name_entities = team_name.split(" ")
                if word in team_name_entities:
                    names_present.add((inv_team_map[team_name], word))
                                
        sentences = set()
        for name in names_present:
            for match in re.finditer(name[1], article):
                start = match.start()
                sent_end = start
                while True:
                    sent_end += 1
                    if article[sent_end:sent_end+2] == '. ' or sent_end > len(article) - 1:
                        break

                sent_begin = start
                while True:
                    sent_begin -= 1
                    if article[sent_begin] == '.' or sent_begin == 0:
                        break

                sentences.add((name[0], article[sent_begin+2:sent_end+1]))
                
        all_events = []
        for (name, s) in sentences:
            sent_words = s.split()
            for word in sent_words:
                if word.isdigit():
                    all_events.append((name, int(word), s))
                else:
                    try:
                        number = w2n.word_to_num(word)
                        split = s.split(" ")
                        i = split.index(word)
                        if "scored" in split or "points" in split:
                            all_events.append((name, number, s))
                    except:
                        continue

        game_event_space = str_to_tup(event_space['tuples'][idx])
        game_event_space = [tuple(i) for i in game_event_space]
        
        home_team = event_space['home_team'][idx]
        away_team = event_space['away_team'][idx]

        all_records = set()
        all_sent = set()
        for event in all_events:
            for record in game_event_space:
                if record[0] == event[0] and str(event[1]) == record[2]:
                    should_write = parse_event_by_sentence(record[0], record[1], record[2], event[2])
                    if should_write:
                        try:
                            tokened_event = replace_sentence_with_tokens(record, event[2])
                            label_writer.writerow((record, tokened_event))
                        except UnicodeEncodeError:
                            print(record, event[2])
        #label_writer.writerow((home_team, away_team, all_records, ''.join(all_sent)))
    outFile.close()
# Out:
# 2010 0
# 2010 100
# 2010 200
# 2010 300
# 2010 400
# 2010 500
# 2010 600
# 2010 700
# 2010 800
# 2010 900
# 2010 1000
# 2010 1100
# 2010 1200
# 2011 0
# 2011 100
# 2011 200
# 2011 300
# 2011 400
# 2011 500
# 2011 600
# 2011 700
# 2011 800
# 2011 900
# 2011 1000
# 2011 1100
# 2011 1200
# 2012 0
# 2012 100
# 2012 200
# 2012 300
# 2012 400
# 2012 500
# 2012 600
# 2012 700
# 2012 800
# 2012 900
# 2012 1000
# 2012 1100
# 2012 1200
# 2013 0
# 2013 100
# 2013 200
# 2013 300
# 2013 400
# 2013 500
# 2013 600
# 2013 700
# 2013 800
# 2013 900
# 2013 1000
# 2013 1100
# 2013 1200
# 2014 0
# 2014 100
# 2014 200
# 2014 300
# 2014 400
# 2014 500
# 2014 600
